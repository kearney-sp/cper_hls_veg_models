# %%
from fsspec.implementations import zip
from glob import glob
import pandas as pd
import numpy as np
import os
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import datetime

# %%
outPATH = '../data/sensors/par/neon_d10_cper_par_cln.csv'

# %%
for yr in range(2014, 2023):
    zdirs = glob('/mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.' + str(yr) + '*')

    for zdir in tqdm(zdirs):
        print(zdir)
        if os.path.isdir(zdir):
            for f in glob(os.path.join(zdir, '*30min*.csv')):
                #print('\t' + f)
                try:
                    df
                except NameError:
                    df = pd.read_csv(f, parse_dates=True)
                else:
                    df_tmp = pd.read_csv(f, parse_dates=True)
                    df = pd.concat([df, df_tmp])
        else:
            if '.zip' in zdir:
                fs = zip.ZipFileSystem(zdir)
                for f in fs.glob('*30min*.csv'):
                    with fs.open(f) as src:
                        try:
                            df
                        except NameError:
                            df = pd.read_csv(src)
                        else:
                            df_tmp = pd.read_csv(src)
                            df = pd.concat([df, df_tmp])
            else:
                print('ERROR: not a directory or .zip file: ' + zdir)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-07.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-08.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-09.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-10.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-11.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2014-12.basic.20230127T120753Z.RELEASE-2023
#   0%|          | 0/12 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-01.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-07.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-08.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-09.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-10.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-11.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2015-12.basic.20230127T120753Z.RELEASE-2023
#   0%|          | 0/12 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-01.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-07.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-08.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-09.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-10.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-11.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2016-12.basic.20230127T120753Z.RELEASE-2023
#   0%|          | 0/12 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-01.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-07.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-08.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-09.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-10.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-11.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2017-12.basic.20230127T120753Z.RELEASE-2023
#   0%|          | 0/12 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-01.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-07.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-08.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-09.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-10.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-11.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2018-12.basic.20230127T120753Z.RELEASE-2023
#   0%|          | 0/12 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-01.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-07.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-08.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-09.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-10.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-11.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2019-12.basic.20230127T120753Z.RELEASE-2023
#   0%|          | 0/12 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-01.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-07.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-08.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-09.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-10.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-11.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2020-12.basic.20230127T120753Z.RELEASE-2023
#   0%|          | 0/12 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-01.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-07.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-08.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-09.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-10.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-11.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2021-12.basic.20230127T120753Z.RELEASE-2023
#   0%|          | 0/12 [00:00<?, ?it/s]
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-01.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-02.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-03.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-04.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-05.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-06.basic.20230127T120753Z.RELEASE-2023
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-07.basic.20221201T031826Z.PROVISIONAL
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-08.basic.20221201T085356Z.PROVISIONAL
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-09.basic.20221002T201902Z.PROVISIONAL
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-10.basic.20221107T190615Z.PROVISIONAL
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-11.basic.20221215T173127Z.PROVISIONAL
# /mnt/d/CPER/data/climate/PAR/NEON_par/NEON.D10.CPER.DP1.00024.001.2022-12.basic.20230103T231747Z.PROVISIONAL

# %%
np.sum(df['PARMean'].interpolate().groupby(pd.to_datetime(df['startDateTime'], utc=True).dt.date).count() == 384)
# Out:
# 3238

# %%
df = df.groupby('startDateTime').mean().reset_index()

# %%
df = df.reset_index()

# %%
par_mask = df.groupby(pd.to_datetime(df['startDateTime'], utc=True).dt.date).apply(lambda x: x['PARMean'].isnull().any())

# %%
par_mask.index[par_mask]
# Out:
# Index([2014-02-18, 2014-04-10, 2014-04-25, 2014-05-21, 2014-06-03, 2014-06-04,
#        2014-06-05, 2014-06-06, 2014-06-07, 2014-07-26,
#        ...
#        2021-09-22, 2021-10-26, 2021-12-15, 2021-12-16, 2022-04-27, 2022-08-10,
#        2022-09-22, 2022-09-23, 2022-10-25, 2022-12-14],
#       dtype='object', name='startDateTime', length=116)

# %%
df_daily_par = df['PARMean'].apply(lambda x: x*0.219*1800).groupby(pd.to_datetime(df['startDateTime'], utc=True).dt.date).sum()/1e6

# %%
df_daily_par[par_mask.index[par_mask]] = np.nan

# %%
df_daily_par = df_daily_par.interpolate()

# %%
fig, ax1 = plt.subplots(figsize=(20,4))
df_daily_par.plot(ax=ax1)
# Out:
# <AxesSubplot:xlabel='startDateTime'>

# %%
df_daily_par.name = 'PAR_MJ_m2_day'

# %%
df_daily_par.reset_index().to_csv(outPATH, index=False)
