# %%
import rioxarray as riox
import xarray as xr
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
outDIR = '/90daydata/cper_neon_aop/hls_nrt/cper/lmf_biomass/'

# %%
yr = 2000

# %%
xr_bm = xr.open_dataset(
    os.path.join(outDIR, 
                 'cper_lmf_bm_'+str(yr)+'.nc'))

# %%
xr_bm
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 310, y: 323, x: 323)
# Coordinates:
#   * time         (time) datetime64[ns] 2000-02-24 2000-02-25 ... 2000-12-30
#   * y            (y) float64 4.524e+06 4.524e+06 ... 4.515e+06 4.515e+06
#   * x            (x) float64 5.176e+05 5.176e+05 ... 5.272e+05 5.273e+05
#     YEAR         int32 ...
#     spatial_ref  int64 ...
# Data variables:
#     Biomass      (time, y, x) float32 ...

# %%
xr_bm.rio.transform()
# Out:
# Affine(30.0, 0.0, 517605.0,
#        0.0, -30.0, 4524375.0)

# %%
test1 = xr_bm['Biomass'].isel(x=250, y=150).values

# %%
fig, ax = plt.subplots()
ax.plot(test1)

# %%
from rasterio.plot import show

# %%
show(xr_bm['Biomass'].sortby('y', ascending=False).isel(time=150).data, vmin=200, vmax=1500)
# Out:
# <AxesSubplot:>
